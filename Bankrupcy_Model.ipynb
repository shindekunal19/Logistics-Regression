# %% [markdown]
# #Important Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# # Read Data

# %%
df = pd.read_csv("Bankrupt.csv")

# %%
df
# Out:
#       Bankrupt   OperatingGrossMargin   OperatingProfitRate   Cashflowrate  \
# 0            1               0.601457              0.998969       0.458143
# 1            1               0.610235              0.998946       0.461867
# 2            1               0.601450              0.998857       0.458521
# 3            1               0.583541              0.998700       0.465705
# 4            1               0.598783              0.998973       0.462746
# ...        ...                    ...                   ...            ...
# 2099         1               0.586373              0.998692       0.462969
# 2100         1               0.604138              0.999018       0.468037
# 2101         0               0.578850              0.998423       0.461735
# 2102         0               0.612130              0.999114       0.497840
# 2103         0               0.599158              0.998995       0.460361
#
#        NetValuePerShare(A)   PersistentEPSintheLastFourSeasons  \
# ...

# %% [markdown]
# #Explore Data in Depth

# %%
df.shape
# Out:
# (2104, 10)

# %%
df.columns
# Out:
# Index(['Bankrupt', ' OperatingGrossMargin', ' OperatingProfitRate',
#        ' Cashflowrate', ' NetValuePerShare(A)',
#        ' PersistentEPSintheLastFourSeasons', ' TotalAssetTurnover',
#        ' WorkingCapitaltoTotalAssets', ' CurrentLiabilitytoAssets',
#        ' EquitytoLiability'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Bankrupt                                int64
#  OperatingGrossMargin                 float64
#  OperatingProfitRate                  float64
#  Cashflowrate                         float64
#  NetValuePerShare(A)                  float64
#  PersistentEPSintheLastFourSeasons    float64
#  TotalAssetTurnover                   float64
#  WorkingCapitaltoTotalAssets          float64
#  CurrentLiabilitytoAssets             float64
#  EquitytoLiability                    float64
# dtype: object

# %%
df.count()
# Out:
# Bankrupt                              2104
#  OperatingGrossMargin                 2104
#  OperatingProfitRate                  2104
#  Cashflowrate                         2104
#  NetValuePerShare(A)                  2104
#  PersistentEPSintheLastFourSeasons    2104
#  TotalAssetTurnover                   2104
#  WorkingCapitaltoTotalAssets          2104
#  CurrentLiabilitytoAssets             2104
#  EquitytoLiability                    2104
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Bankrupt                              0
#  OperatingGrossMargin                 0
#  OperatingProfitRate                  0
#  Cashflowrate                         0
#  NetValuePerShare(A)                  0
#  PersistentEPSintheLastFourSeasons    0
#  TotalAssetTurnover                   0
#  WorkingCapitaltoTotalAssets          0
#  CurrentLiabilitytoAssets             0
#  EquitytoLiability                    0
# dtype: int64

# %%
df.head()
# Out:
#    Bankrupt   OperatingGrossMargin   OperatingProfitRate   Cashflowrate  \
# 0         1               0.601457              0.998969       0.458143
# 1         1               0.610235              0.998946       0.461867
# 2         1               0.601450              0.998857       0.458521
# 3         1               0.583541              0.998700       0.465705
# 4         1               0.598783              0.998973       0.462746
#
#     NetValuePerShare(A)   PersistentEPSintheLastFourSeasons  \
# 0              0.147950                            0.169141
# 1              0.182251                            0.208944
# 2              0.177911                            0.180581
# 3              0.154187                            0.193722
# 4              0.167502                            0.212537
#
#     TotalAssetTurnover   WorkingCapitaltoTotalAssets  \
# 0             0.086957                      0.672775
# 1             0.064468                      0.751111
# ...

# %%
df.head(10)
# Out:
#    Bankrupt   OperatingGrossMargin   OperatingProfitRate   Cashflowrate  \
# 0         1               0.601457              0.998969       0.458143
# 1         1               0.610235              0.998946       0.461867
# 2         1               0.601450              0.998857       0.458521
# 3         1               0.583541              0.998700       0.465705
# 4         1               0.598783              0.998973       0.462746
# 5         1               0.590171              0.998758       0.465861
# 6         0               0.619950              0.998993       0.461020
# 7         0               0.601738              0.000000       0.467024
# 8         0               0.603612              0.000000       0.463142
# 9         0               0.599209              0.000000       0.470575
#
#     NetValuePerShare(A)   PersistentEPSintheLastFourSeasons  \
# 0              0.147950                            0.169141
# ...

# %%
df[" Cashflowrate"].head()
# Out:
# 0    0.458143
# 1    0.461867
# 2    0.458521
# 3    0.465705
# 4    0.462746
# Name:  Cashflowrate, dtype: float64

# %%
df.tail()
# Out:
#       Bankrupt   OperatingGrossMargin   OperatingProfitRate   Cashflowrate  \
# 2099         1               0.586373              0.998692       0.462969
# 2100         1               0.604138              0.999018       0.468037
# 2101         0               0.578850              0.998423       0.461735
# 2102         0               0.612130              0.999114       0.497840
# 2103         0               0.599158              0.998995       0.460361
#
#        NetValuePerShare(A)   PersistentEPSintheLastFourSeasons  \
# 2099              0.132359                            0.127541
# 2100              0.179596                            0.223882
# 2101              0.172770                            0.202893
# 2102              0.179259                            0.219438
# 2103              0.172980                            0.210646
#
#        TotalAssetTurnover   WorkingCapitaltoTotalAssets  \
# 2099             0.041979                      0.760041
# ...

# %%
df.tail(10)
# Out:
#       Bankrupt   OperatingGrossMargin   OperatingProfitRate   Cashflowrate  \
# 2094         1               0.603461              0.998898       0.462776
# 2095         1               0.611439              0.999171       0.454104
# 2096         1               0.603381              0.998977       0.468616
# 2097         1               0.610415              0.999087       0.455337
# 2098         1               0.603490              0.999038       0.461530
# 2099         1               0.586373              0.998692       0.462969
# 2100         1               0.604138              0.999018       0.468037
# 2101         0               0.578850              0.998423       0.461735
# 2102         0               0.612130              0.999114       0.497840
# 2103         0               0.599158              0.998995       0.460361
#
#        NetValuePerShare(A)   PersistentEPSintheLastFourSeasons  \
# 2094              0.151321                            0.204595
# ...

# %%
df.sample()
# Out:
#       Bankrupt   OperatingGrossMargin   OperatingProfitRate   Cashflowrate  \
# 1685         0               0.627567              0.999281        0.44246
#
#        NetValuePerShare(A)   PersistentEPSintheLastFourSeasons  \
# 1685              0.220598                            0.258296
#
#        TotalAssetTurnover   WorkingCapitaltoTotalAssets  \
# 1685              0.13943                      0.905308
#
#        CurrentLiabilitytoAssets   EquitytoLiability
# 1685                   0.042395            0.096373

# %%
df.sample(5)
# Out:
#       Bankrupt   OperatingGrossMargin   OperatingProfitRate   Cashflowrate  \
# 1526         0               0.599828              0.998959       0.380613
# 874          0               0.613363              0.999057       0.468520
# 1983         0               0.598949              0.998992       0.471481
# 1920         0               0.598185              0.998985       0.461387
# 1784         0               0.613738              0.999051       0.464009
#
#        NetValuePerShare(A)   PersistentEPSintheLastFourSeasons  \
# 1526              0.212970                            0.158173
# 874               0.207745                            0.225300
# 1983              0.174413                            0.227286
# 1920              0.175130                            0.223977
# 1784              0.174413                            0.223598
#
#        TotalAssetTurnover   WorkingCapitaltoTotalAssets  \
# 1526             0.160420                      0.968402
# ...

# %%
df[10:20]
# Out:
#     Bankrupt   OperatingGrossMargin   OperatingProfitRate   Cashflowrate  \
# 10         0               0.614026              0.000000       0.464818
# 11         0               0.623712              0.000000       0.465491
# 12         0               0.608131              0.000000       0.464100
# 13         0               0.600578              0.000000       0.467198
# 14         0               0.604686              0.999053       0.478767
# 15         0               0.621773              0.999097       0.472093
# 16         0               0.606524              0.998996       0.462196
# 17         0               0.618451              0.999119       0.470062
# 18         0               0.598344              0.998989       0.468443
# 19         0               0.636259              0.999042       0.465164
#
#      NetValuePerShare(A)   PersistentEPSintheLastFourSeasons  \
# 10              0.182925                            0.218966
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2104 entries, 0 to 2103
# Data columns (total 10 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Bankrupt                            2104 non-null   int64
#  1    OperatingGrossMargin               2104 non-null   float64
#  2    OperatingProfitRate                2104 non-null   float64
#  3    Cashflowrate                       2104 non-null   float64
#  4    NetValuePerShare(A)                2104 non-null   float64
#  5    PersistentEPSintheLastFourSeasons  2104 non-null   float64
#  6    TotalAssetTurnover                 2104 non-null   float64
#  7    WorkingCapitaltoTotalAssets        2104 non-null   float64
#  8    CurrentLiabilitytoAssets           2104 non-null   float64
#  9    EquitytoLiability                  2104 non-null   float64
# dtypes: float64(9), int64(1)
# memory usage: 164.5 KB

# %%
df.describe()
# Out:
#           Bankrupt   OperatingGrossMargin   OperatingProfitRate  \
# count  2104.000000            2104.000000           2104.000000
# mean      0.063213               0.604994              0.995592
# std       0.243403               0.015359              0.057543
# min       0.000000               0.156308              0.000000
# 25%       0.000000               0.599178              0.998955
# 50%       0.000000               0.603789              0.999004
# 75%       0.000000               0.609405              0.999052
# max       1.000000               0.665151              0.999458
#
#         Cashflowrate   NetValuePerShare(A)  \
# count    2104.000000           2104.000000
# mean        0.465056              0.182145
# std         0.011326              0.022439
# min         0.306652              0.000000
# 25%         0.460996              0.171327
# 50%         0.463927              0.179301
# 75%         0.468006              0.191343
# ...

# %%
df.describe().T
# Out:
#                                      count      mean       std       min  \
# Bankrupt                            2104.0  0.063213  0.243403  0.000000
#  OperatingGrossMargin               2104.0  0.604994  0.015359  0.156308
#  OperatingProfitRate                2104.0  0.995592  0.057543  0.000000
#  Cashflowrate                       2104.0  0.465056  0.011326  0.306652
#  NetValuePerShare(A)                2104.0  0.182145  0.022439  0.000000
#  PersistentEPSintheLastFourSeasons  2104.0  0.220096  0.021349  0.000000
#  TotalAssetTurnover                 2104.0  0.132132  0.089851  0.000000
#  WorkingCapitaltoTotalAssets        2104.0  0.796720  0.052730  0.494210
#  CurrentLiabilitytoAssets           2104.0  0.094086  0.049561  0.000000
#  EquitytoLiability                  2104.0  0.040612  0.037042  0.008753
#
#                                          25%       50%       75%       max
# Bankrupt                            0.000000  0.000000  0.000000  1.000000
# ...

# %%
df['Bankrupt'].value_counts()
# Out:
# 0    1971
# 1     133
# Name: Bankrupt, dtype: int64

# %%
df.groupby('Bankrupt').size()
# Out:
# Bankrupt
# 0    1971
# 1     133
# dtype: int64

# %% [markdown]
# #Visualization of Data

# %%
df.hist(figsize = (20,20))
# Out:
# array([[<Axes: title={'center': 'Bankrupt'}>,
#         <Axes: title={'center': ' OperatingGrossMargin'}>,
#         <Axes: title={'center': ' OperatingProfitRate'}>],
#        [<Axes: title={'center': ' Cashflowrate'}>,
#         <Axes: title={'center': ' NetValuePerShare(A)'}>,
#         <Axes: title={'center': ' PersistentEPSintheLastFourSeasons'}>],
#        [<Axes: title={'center': ' TotalAssetTurnover'}>,
#         <Axes: title={'center': ' WorkingCapitaltoTotalAssets'}>,
#         <Axes: title={'center': ' CurrentLiabilitytoAssets'}>],
#        [<Axes: title={'center': ' EquitytoLiability'}>, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
sn.pairplot(df, hue = 'Bankrupt')

# %%
df.corr()
# Out:
#                                     Bankrupt   OperatingGrossMargin  \
# Bankrupt                            1.000000              -0.103597
#  OperatingGrossMargin              -0.103597               1.000000
#  OperatingProfitRate                0.014362              -0.004348
#  Cashflowrate                      -0.091595               0.140715
#  NetValuePerShare(A)               -0.219503               0.144554
#  PersistentEPSintheLastFourSeasons -0.346132               0.263831
#  TotalAssetTurnover                -0.101691              -0.035132
#  WorkingCapitaltoTotalAssets       -0.235626               0.204509
#  CurrentLiabilitytoAssets           0.268545              -0.104732
#  EquitytoLiability                 -0.103372               0.081947
#
#                                      OperatingProfitRate   Cashflowrate  \
# Bankrupt                                        0.014362      -0.091595
#  OperatingGrossMargin                          -0.004348       0.140715
# ...

# %%
sn.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sn.countplot(x='Bankrupt',data=df)
plt.show()

# %%
sn.boxplot(x=' Cashflowrate',data=df)
plt.show()

# %%
sn.scatterplot(x=' OperatingProfitRate', y=' TotalAssetTurnover',data=df)
plt.show()

# %%
sn.distplot(df[' OperatingProfitRate'])
# Out:
# C:\Temp\ipykernel_16604\607039866.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[' OperatingProfitRate'])
# <Axes: xlabel=' OperatingProfitRate', ylabel='Density'>

# %%
sn.jointplot(x=' NetValuePerShare(A)',y=' PersistentEPSintheLastFourSeasons',data=df)

# %%
sn.kdeplot(df[' TotalAssetTurnover'])
# Out:
# <Axes: xlabel=' TotalAssetTurnover', ylabel='Density'>

# %% [markdown]
# #Data Cleaning

# %%
df.describe()
# Out:
#           Bankrupt   OperatingGrossMargin   OperatingProfitRate  \
# count  2104.000000            2104.000000           2104.000000
# mean      0.063213               0.604994              0.995592
# std       0.243403               0.015359              0.057543
# min       0.000000               0.156308              0.000000
# 25%       0.000000               0.599178              0.998955
# 50%       0.000000               0.603789              0.999004
# 75%       0.000000               0.609405              0.999052
# max       1.000000               0.665151              0.999458
#
#         Cashflowrate   NetValuePerShare(A)  \
# count    2104.000000           2104.000000
# mean        0.465056              0.182145
# std         0.011326              0.022439
# min         0.306652              0.000000
# 25%         0.460996              0.171327
# 50%         0.463927              0.179301
# 75%         0.468006              0.191343
# ...

# %%
df.columns
# Out:
# Index(['Bankrupt', ' OperatingGrossMargin', ' OperatingProfitRate',
#        ' Cashflowrate', ' NetValuePerShare(A)',
#        ' PersistentEPSintheLastFourSeasons', ' TotalAssetTurnover',
#        ' WorkingCapitaltoTotalAssets', ' CurrentLiabilitytoAssets',
#        ' EquitytoLiability'],
#       dtype='object')

# %% [markdown]
# Can minimum value of below listed columns be zero (0)?
#
# On these columns, a value of zero does not make sense and thus indicates missing value.
#
# Following columns or variables have an invalid zero value:
#
# #Glucose
# #BloodPressure
# #SkinThickness
# #Insulin
# #BMI

# %% [markdown]
# #It is better to replace zeros with nan since after that counting them would be easier and zeros need to be replaced with suitable values

# %%
df_copy = df.copy(deep = True)
df_copy[['Bankrupt', ' OperatingGrossMargin', ' OperatingProfitRate',
       ' Cashflowrate', ' NetValuePerShare(A)',
       ' PersistentEPSintheLastFourSeasons', ' TotalAssetTurnover',
       ' WorkingCapitaltoTotalAssets', ' CurrentLiabilitytoAssets',
       ' EquitytoLiability']]=df_copy[['Bankrupt', ' OperatingGrossMargin', ' OperatingProfitRate',
       ' Cashflowrate', ' NetValuePerShare(A)',
       ' PersistentEPSintheLastFourSeasons', ' TotalAssetTurnover',
       ' WorkingCapitaltoTotalAssets', ' CurrentLiabilitytoAssets',
       ' EquitytoLiability']].replace(0,np.NaN)

# %%
df_copy.head(10)
# Out:
#    Bankrupt   OperatingGrossMargin   OperatingProfitRate   Cashflowrate  \
# 0       1.0               0.601457              0.998969       0.458143
# 1       1.0               0.610235              0.998946       0.461867
# 2       1.0               0.601450              0.998857       0.458521
# 3       1.0               0.583541              0.998700       0.465705
# 4       1.0               0.598783              0.998973       0.462746
# 5       1.0               0.590171              0.998758       0.465861
# 6       NaN               0.619950              0.998993       0.461020
# 7       NaN               0.601738                   NaN       0.467024
# 8       NaN               0.603612                   NaN       0.463142
# 9       NaN               0.599209                   NaN       0.470575
#
#     NetValuePerShare(A)   PersistentEPSintheLastFourSeasons  \
# 0              0.147950                            0.169141
# ...

# %%
df_copy.isnull().sum()
# Out:
# Bankrupt                              1971
#  OperatingGrossMargin                    0
#  OperatingProfitRate                     7
#  Cashflowrate                            0
#  NetValuePerShare(A)                     5
#  PersistentEPSintheLastFourSeasons       1
#  TotalAssetTurnover                      7
#  WorkingCapitaltoTotalAssets             0
#  CurrentLiabilitytoAssets                7
#  EquitytoLiability                       0
# dtype: int64

# %%
df_copy.describe()
# Out:
#        Bankrupt   OperatingGrossMargin   OperatingProfitRate   Cashflowrate  \
# count     133.0            2104.000000           2097.000000    2104.000000
# mean        1.0               0.604994              0.998916       0.465056
# std         0.0               0.015359              0.000951       0.011326
# min         1.0               0.156308              0.973424       0.306652
# 25%         1.0               0.599178              0.998956       0.460996
# 50%         1.0               0.603789              0.999005       0.463927
# 75%         1.0               0.609405              0.999052       0.468006
# max         1.0               0.665151              0.999458       0.598624
#
#         NetValuePerShare(A)   PersistentEPSintheLastFourSeasons  \
# count           2099.000000                         2103.000000
# mean               0.182579                            0.220200
# std                0.020626                            0.020807
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2104 entries, 0 to 2103
# Data columns (total 10 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Bankrupt                            133 non-null    float64
#  1    OperatingGrossMargin               2104 non-null   float64
#  2    OperatingProfitRate                2097 non-null   float64
#  3    Cashflowrate                       2104 non-null   float64
#  4    NetValuePerShare(A)                2099 non-null   float64
#  5    PersistentEPSintheLastFourSeasons  2103 non-null   float64
#  6    TotalAssetTurnover                 2097 non-null   float64
#  7    WorkingCapitaltoTotalAssets        2104 non-null   float64
#  8    CurrentLiabilitytoAssets           2097 non-null   float64
#  9    EquitytoLiability                  2104 non-null   float64
# dtypes: float64(10)
# memory usage: 164.5 KB

# %%
df_copy[' OperatingProfitRate'].fillna(df_copy[' OperatingProfitRate'].mean(), inplace = True)

# %%
df_copy[' NetValuePerShare(A)'].fillna(df_copy[' NetValuePerShare(A)'].mean(), inplace = True)

# %%
df_copy[' TotalAssetTurnover'].fillna(df_copy[' TotalAssetTurnover'].median(), inplace = True)

# %%
df_copy[' CurrentLiabilitytoAssets'].fillna(df_copy[' CurrentLiabilitytoAssets'].median(), inplace = True)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2104 entries, 0 to 2103
# Data columns (total 10 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Bankrupt                            133 non-null    float64
#  1    OperatingGrossMargin               2104 non-null   float64
#  2    OperatingProfitRate                2104 non-null   float64
#  3    Cashflowrate                       2104 non-null   float64
#  4    NetValuePerShare(A)                2104 non-null   float64
#  5    PersistentEPSintheLastFourSeasons  2103 non-null   float64
#  6    TotalAssetTurnover                 2104 non-null   float64
#  7    WorkingCapitaltoTotalAssets        2104 non-null   float64
#  8    CurrentLiabilitytoAssets           2104 non-null   float64
#  9    EquitytoLiability                  2104 non-null   float64
# dtypes: float64(10)
# memory usage: 164.5 KB

# %% [markdown]
# If there is a dataset that have great outliers,
# I'll prefer median.
# E.x.: 99% of household income is below 100, and 1% is above 500.
#
# On the other hand,
# if we work with wear of clothes that customers give to dry-cleaner
# (assuming that dry-cleaners' operators fill this field intuitively),
# I'll fill missings with mean value of wear.

# %%
sn.boxplot(x=' TotalAssetTurnover',data=df_copy)
plt.show()

# %%
df_copy.describe()
# Out:
#        Bankrupt   OperatingGrossMargin   OperatingProfitRate   Cashflowrate  \
# count     133.0            2104.000000           2104.000000    2104.000000
# mean        1.0               0.604994              0.998916       0.465056
# std         0.0               0.015359              0.000950       0.011326
# min         1.0               0.156308              0.973424       0.306652
# 25%         1.0               0.599178              0.998955       0.460996
# 50%         1.0               0.603789              0.999004       0.463927
# 75%         1.0               0.609405              0.999052       0.468006
# max         1.0               0.665151              0.999458       0.598624
#
#         NetValuePerShare(A)   PersistentEPSintheLastFourSeasons  \
# count           2104.000000                         2103.000000
# mean               0.182579                            0.220200
# std                0.020602                            0.020807
# ...

# %% [markdown]
# #Scaling the data
# #Outlier!!! The Silent Killer

# %%
df_copy.columns
# Out:
# Index(['Bankrupt', ' OperatingGrossMargin', ' OperatingProfitRate',
#        ' Cashflowrate', ' NetValuePerShare(A)',
#        ' PersistentEPSintheLastFourSeasons', ' TotalAssetTurnover',
#        ' WorkingCapitaltoTotalAssets', ' CurrentLiabilitytoAssets',
#        ' EquitytoLiability'],
#       dtype='object')

# %%
sn.boxplot(x='Bankrupt', y=' CurrentLiabilitytoAssets',data=df_copy)
plt.show()

# %%
sn.boxplot(x='Bankrupt', y=' Cashflowrate',data=df_copy)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaler.fit(df_copy.drop('Bankrupt',axis=1))
# Out:
# StandardScaler()

# %%
scaled_features = scaler.transform(df.drop('Bankrupt',axis=1))

# %%
scaled_features
# Out:
# array([[-0.2303362 ,  0.05649859, -0.61055173, ..., -2.35113654,
#          1.07464558, -0.65193985],
#        [ 0.34132936,  0.03203963, -0.28165147, ..., -0.86517539,
#         -0.75971874, -0.53513876],
#        [-0.23080556, -0.06129408, -0.57721732, ...,  0.62183614,
#          0.07678456, -0.65179476],
#        ...,
#        [-1.70267992, -0.51822537, -0.2933556 , ...,  0.06354045,
#         -0.70732173, -0.09177909],
#        [ 0.46476779,  0.20921517,  2.89534783, ...,  2.96265609,
#         -1.41161803,  2.263473  ],
#        [-0.38005808,  0.08400004, -0.41469315, ..., -0.23644961,
#          0.46549543, -0.36808723]])

# %%
df_feat = pd.DataFrame(scaled_features,columns=df.columns[:-1])
df_feat.head()
# Out:
#    Bankrupt   OperatingGrossMargin   OperatingProfitRate   Cashflowrate  \
# 0 -0.230336               0.056499             -0.610552      -1.681266
# 1  0.341329               0.032040             -0.281651      -0.015898
# 2 -0.230806              -0.061294             -0.577217      -0.226627
# 3 -1.397135              -0.227274              0.057323      -1.378472
# 4 -0.404464               0.060636             -0.204019      -0.731966
#
#     NetValuePerShare(A)   PersistentEPSintheLastFourSeasons  \
# 0             -2.454499                           -0.508868
# 1             -0.541105                           -0.760106
# 2             -1.904569                           -1.312829
# 3             -1.272830                           -0.475370
# 4             -0.368399                            0.479334
#
#     TotalAssetTurnover   WorkingCapitaltoTotalAssets  \
# 0            -2.351137                      1.074646
# 1            -0.865175                     -0.759719
# ...

# %%
df_feat['Bankrupt']= df['Bankrupt']

# %%
df_feat.head()
# Out:
#    Bankrupt   OperatingGrossMargin   OperatingProfitRate   Cashflowrate  \
# 0         1               0.056499             -0.610552      -1.681266
# 1         1               0.032040             -0.281651      -0.015898
# 2         1              -0.061294             -0.577217      -0.226627
# 3         1              -0.227274              0.057323      -1.378472
# 4         1               0.060636             -0.204019      -0.731966
#
#     NetValuePerShare(A)   PersistentEPSintheLastFourSeasons  \
# 0             -2.454499                           -0.508868
# 1             -0.541105                           -0.760106
# 2             -1.904569                           -1.312829
# 3             -1.272830                           -0.475370
# 4             -0.368399                            0.479334
#
#     TotalAssetTurnover   WorkingCapitaltoTotalAssets  \
# 0            -2.351137                      1.074646
# 1            -0.865175                     -0.759719
# ...

# %%
sn.boxplot(x='Bankrupt',y=' Cashflowrate',data=df_feat)
plt.show()

# %%
sn.boxplot(x='Bankrupt', y=' TotalAssetTurnover',data=df_feat)
plt.show()

# %% [markdown]
# # Decide Dependant and Independant Elements in Data Set

# %%
x=df_feat.drop('Bankrupt',axis=1)

# %%
x
# Out:
#        OperatingGrossMargin   OperatingProfitRate   Cashflowrate  \
# 0                  0.056499             -0.610552      -1.681266
# 1                  0.032040             -0.281651      -0.015898
# 2                 -0.061294             -0.577217      -0.226627
# 3                 -0.227274              0.057323      -1.378472
# 4                  0.060636             -0.204019      -0.731966
# ...                     ...                   ...            ...
# 2099              -0.235670             -0.184315      -2.438252
# 2100               0.107850              0.263256      -0.144791
# 2101              -0.518225             -0.293356      -0.476227
# 2102               0.209215              2.895348      -0.161158
# 2103               0.084000             -0.414693      -0.465998
#
#        NetValuePerShare(A)   PersistentEPSintheLastFourSeasons  \
# 0                -2.454499                           -0.508868
# ...

# %%
y=df_feat['Bankrupt']

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2099    1
# 2100    1
# 2101    0
# 2102    0
# 2103    0
# Name: Bankrupt, Length: 2104, dtype: int64

# %% [markdown]
# #Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test =train_test_split(x,y,test_size=0.3)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1472 entries, 871 to 1550
# Data columns (total 8 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0    OperatingGrossMargin               1472 non-null   float64
#  1    OperatingProfitRate                1472 non-null   float64
#  2    Cashflowrate                       1472 non-null   float64
#  3    NetValuePerShare(A)                1472 non-null   float64
#  4    PersistentEPSintheLastFourSeasons  1472 non-null   float64
#  5    TotalAssetTurnover                 1472 non-null   float64
#  6    WorkingCapitaltoTotalAssets        1472 non-null   float64
#  7    CurrentLiabilitytoAssets           1472 non-null   float64
# dtypes: float64(8)
# memory usage: 103.5 KB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 632 entries, 366 to 1047
# Data columns (total 8 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0    OperatingGrossMargin               632 non-null    float64
#  1    OperatingProfitRate                632 non-null    float64
#  2    Cashflowrate                       632 non-null    float64
#  3    NetValuePerShare(A)                632 non-null    float64
#  4    PersistentEPSintheLastFourSeasons  632 non-null    float64
#  5    TotalAssetTurnover                 632 non-null    float64
#  6    WorkingCapitaltoTotalAssets        632 non-null    float64
#  7    CurrentLiabilitytoAssets           632 non-null    float64
# dtypes: float64(8)
# memory usage: 44.4 KB

# %% [markdown]
# #Machine Learning Models
#
# 1. Linear
# 2. Logistic
# 3. SVC
# 4. KNN
# 5. K Mean
# 6. Desicion Tree
# 7. Random Forest
# 8. Naive Bayes

# %% [markdown]
# #Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
predictions = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       595
#            1       0.56      0.24      0.34        37
#
#     accuracy                           0.94       632
#    macro avg       0.76      0.62      0.66       632
# weighted avg       0.93      0.94      0.93       632

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[588   7]
#  [ 28   9]]

# %% [markdown]
# #SMV

# %%
from sklearn.svm import SVC

# %%
SVM = SVC()

# %%
SVM.fit(X_train,y_train)

# %%
predictions = SVM.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))

# %% [markdown]
# #KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(X_train,y_train)

# %%
predictions = knn.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))

# %% [markdown]
# #K Mean

# %%
from sklearn.cluster import KMeans

# %%
Kmean = KMeans(n_clusters=2)

# %%
Kmean.fit(X_train,y_train)

# %%
predictions = Kmean.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))

# %% [markdown]
# #Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)

# %%
predictions = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))

# %% [markdown]
# #Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=100)

# %%
rfc.fit(X_train,y_train)

# %%
predictions = rfc.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))

# %% [markdown]
# #Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
 NB= GaussianNB()

# %%
NB.fit(X_train,y_train)

# %%
predictions = NB.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))

# %% [markdown]
# #Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %% [markdown]
# # cannot apply Linear Regression to this Data

# %% [markdown]
# #Linear Discriminant Analysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
LDA = LinearDiscriminantAnalysis()

# %%
LDA.fit(X_train,y_train)

# %%
predictions = LDA.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))
